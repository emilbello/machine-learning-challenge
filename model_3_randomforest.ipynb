# %%
# Updating sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# installing joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selecting all features. Since the data and domain is unknown to me, all the information is selected.
X = df.drop('koi_disposition', axis=1)
y = df['koi_disposition']

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4269              0              0              0              0    8.689108
# 1188              0              0              0              0   89.193574
# 4436              0              1              0              1    1.106570
# 6517              0              0              1              0    1.633454
# 5077              1              0              1              1   12.425336
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4269         0.000034        -0.000034    133.23559           0.00388
# 1188         0.000230        -0.000230    217.82184           0.00204
# 4436         0.000014        -0.000014    132.36650           0.01400
# 6517         0.000029        -0.000029    181.85560           0.01320
# 5077         0.000368        -0.000368    141.58000           0.02760
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4269          -0.00388  ...               0      5.274           0.000
# 1188          -0.00204  ...            -134      4.239           0.143
# 4436          -0.01400  ...            -227      4.387           0.070
# 6517          -0.01320  ...            -241      4.372           0.105
# 5077          -0.02760  ...            -187      4.541           0.072
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4269           0.000     0.118          0.000          0.000  292.50378
# 1188          -0.117     1.295          0.232         -0.211  294.74332
# 4436          -0.224     1.165          0.400         -0.133  293.08490
# 6517          -0.195     1.091          0.353         -0.151  296.93594
# 5077          -0.108     0.783          0.140         -0.081  297.61758
#
#             dec  koi_kepmag
# 4269  41.830421      17.131
# 1188  43.461208      12.487
# 4436  42.150551      14.582
# 6517  44.161045      12.179
# 5077  40.506771      15.539
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Random Forest is a tree-based model and doesn't require feature scaling

# %% [markdown]
# # Train the Model

# %%
# Create the SVC Model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)

# %%
# checking score
print(f"Testing Data Score: {rf.score(X_test, y_test)}")
# Out:
# Testing Data Score: 0.902745995423341

# %%
predictions_rf = rf.predict(X_test)

# %%
feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True) # which one is the most important when predicting diabetes
# Out:
# [(0.10506514116790328, 'koi_fpflag_co'),
#  (0.09547437555352435, 'koi_fpflag_nt'),
#  (0.06762916894401823, 'koi_fpflag_ss'),
#  (0.05852681642114317, 'koi_model_snr'),
#  (0.04394562901010449, 'koi_prad'),
#  (0.03354013097915433, 'koi_duration_err1'),
#  (0.03298436378905555, 'koi_prad_err2'),
#  (0.032065215890715766, 'koi_steff_err1'),
#  (0.03194711977907038, 'koi_prad_err1'),
#  (0.031929547236812766, 'koi_duration_err2'),
#  (0.031138643243160295, 'koi_fpflag_ec'),
#  (0.029778013111959864, 'koi_steff_err2'),
#  (0.02340943080186207, 'koi_duration'),
#  (0.022999636647477062, 'koi_depth'),
#  (0.02286397980182123, 'koi_period'),
#  (0.02179491797406627, 'koi_time0bk_err1'),
#  (0.02177558068095256, 'koi_time0bk_err2'),
#  (0.02119603781843073, 'koi_insol_err1'),
#  (0.02093360195437096, 'koi_impact'),
#  (0.01931639768087477, 'koi_period_err2'),
#  (0.01790742833712079, 'koi_period_err1'),
#  (0.01555145971915647, 'koi_teq'),
#  (0.014849239913437633, 'koi_insol'),
#  (0.014798755445857386, 'koi_insol_err2'),
#  (0.01403474419731102, 'koi_depth_err2'),
#  (0.013180711208971624, 'koi_depth_err1'),
#  (0.012542859998088898, 'ra'),
#  (0.012526447963713917, 'koi_srad_err1'),
#  (0.01239685889895538, 'koi_time0bk'),
#  (0.011122780705246487, 'koi_kepmag'),
#  (0.011082308588521763, 'dec'),
#  (0.010644558237790891, 'koi_impact_err1'),
#  (0.010615969322255649, 'koi_impact_err2'),
#  (0.01031622746724179, 'koi_slogg_err2'),
#  (0.010183784145376698, 'koi_srad'),
#  (0.009665545350647668, 'koi_slogg'),
#  (0.009102487086888747, 'koi_steff'),
#  (0.008978803723407423, 'koi_slogg_err1'),
#  (0.008907963925705207, 'koi_srad_err2'),
#  (0.003277317277826468, 'koi_tce_plnt_num')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# NA

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'emilio_bello_rf.sav'
joblib.dump(predictions_rf, filename)
